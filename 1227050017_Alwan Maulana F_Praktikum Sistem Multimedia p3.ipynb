# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Membaca Gambar

# %%
image1 = cv2.imread(r"D:\Kuliah Semester 6\Praktikum Sistem Multimedia\3\Gambar\wallpaperflare.com_wallpaper(7).jpg")
image2 = cv2.imread(r"D:\Kuliah Semester 6\Praktikum Sistem Multimedia\3\Gambar\wallpaperflare.com_wallpaper(8).jpg")
image3 = cv2.imread(r"D:\Kuliah Semester 6\Praktikum Sistem Multimedia\3\Gambar\wallpaperflare.com_wallpaper(9).jpg")
image4 = cv2.imread(r"D:\Kuliah Semester 6\Praktikum Sistem Multimedia\3\Gambar\wallpaperflare.com_wallpaper(10).jpg")
image5 = cv2.imread(r"D:\Kuliah Semester 6\Praktikum Sistem Multimedia\3\Gambar\wallpaperflare.com_wallpaper(11).jpg")
image6 = cv2.imread(r"D:\Kuliah Semester 6\Praktikum Sistem Multimedia\3\Gambar\wallpaperflare.com_wallpaper(12).jpg")
image7 = cv2.imread(r"D:\Kuliah Semester 6\Praktikum Sistem Multimedia\3\Gambar\wallpaperflare.com_wallpaper(13).jpg")
image8 = cv2.imread(r"D:\Kuliah Semester 6\Praktikum Sistem Multimedia\3\Gambar\wallpaperflare.com_wallpaper(14).jpg")
image9 = cv2.imread(r"D:\Kuliah Semester 6\Praktikum Sistem Multimedia\3\Gambar\wallpaperflare.com_wallpaper(15).jpg")
image10 = cv2.imread(r"D:\Kuliah Semester 6\Praktikum Sistem Multimedia\3\Gambar\wallpaperflare.com_wallpaper(16).jpg")

# %% [markdown]
# ## RESIZE GAMBAR

# %%
resized1 = cv2.resize(image1, (200, 200))
resized2 = cv2.resize(image2, (200, 250))
resized3 = cv2.resize(image3, (250, 200))
resized4 = cv2.resize(image4, (250, 250))
resized5 = cv2.resize(image5, (250, 300))
resized6 = cv2.resize(image6, (300, 250))
resized7 = cv2.resize(image7, (250, 300))
resized8 = cv2.resize(image8, (300, 300))
resized9 = cv2.resize(image9, (300, 350))
resized10 = cv2.resize(image10, (350, 300))

# %% [markdown]
# ## CROP GAMBAR

# %%
cropped1 = image1[50:100, 50:100]
cropped2 = image2[50:150, 50:150]
cropped3 = image3[50:100, 50:150]
cropped4 = image4[50:150, 50:100]
cropped5 = image5[100:150, 100:150]
cropped6 = image6[100:200, 100:200]
cropped7 = image7[100:150, 100:200]
cropped8 = image8[100:200, 100:150]
cropped9 = image9[150:200, 150:200]
cropped10 = image10[150:250, 50:250]

# %% [markdown]
# ## FLIP GAMBAR

# %%
flipped1 = cv2.flip(image1, 1)
flipped2 = cv2.flip(image2, 1)
flipped3 = cv2.flip(image3, 1)
flipped4 = cv2.flip(image4, 1)
flipped5 = cv2.flip(image5, 1)
flipped6 = cv2.flip(image6, 1)
flipped7 = cv2.flip(image7, 1)
flipped8 = cv2.flip(image8, 1)
flipped9 = cv2.flip(image9, 1)
flipped10 = cv2.flip(image10, 1)

# %% [markdown]
# ## ROTATE GAMBAR

# %%
(h1, w1) = image1.shape[:2]
center1 = (w1 / 2, h1 / 2)
M1 = cv2.getRotationMatrix2D(center1, 270, 0.5) # Rotasi 90 derajat
rotated1 = cv2.warpAffine(image1, M1, (w1, h1))

(h2, w2) = image2.shape[:2]
center2 = (w2 / 2, h2 / 2)
M2 = cv2.getRotationMatrix2D(center2, 270, 0.5)
rotated2 = cv2.warpAffine(image2, M2, (w2, h2))

(h3, w3) = image3.shape[:2]
center3 = (w3 / 2, h3 / 2)
M3 = cv2.getRotationMatrix2D(center3, 270, 0.5)
rotated3 = cv2.warpAffine(image3, M3, (w3, h3))

(h4, w4) = image4.shape[:2]
center4 = (w4 / 2, h4 / 2)
M4 = cv2.getRotationMatrix2D(center4, 270, 0.5)
rotated4 = cv2.warpAffine(image4, M4, (w4, h4))

(h5, w5) = image5.shape[:2]
center5 = (w5 / 2, h5 / 2)
M5 = cv2.getRotationMatrix2D(center5, 270, 0.5)
rotated5 = cv2.warpAffine(image5, M5, (w5, h5))

(h6, w6) = image6.shape[:2]
center6 = (w6 / 2, h6 / 2)
M6 = cv2.getRotationMatrix2D(center6, 270, 0.5)
rotated6 = cv2.warpAffine(image6, M6, (w6, h6))

(h7, w7) = image7.shape[:2]
center7 = (w7 / 2, h7 / 2)
M7 = cv2.getRotationMatrix2D(center7, 270, 0.5)
rotated7 = cv2.warpAffine(image7, M7, (w7, h7))

(h8, w8) = image8.shape[:2]
center8 = (w8 / 2, h8 / 2)
M8 = cv2.getRotationMatrix2D(center8, 270, 0.5)
rotated8 = cv2.warpAffine(image8, M8, (w8, h8))

(h9, w9) = image9.shape[:2]
center9 = (w9 / 2, h9 / 2)
M9 = cv2.getRotationMatrix2D(center9, 270, 0.5)
rotated9 = cv2.warpAffine(image9, M9, (w9, h9))

(h10, w10) = image10.shape[:2]
center10 = (w10 / 2, h10 / 2)
M10 = cv2.getRotationMatrix2D(center10, 270, 0.5)
rotated10 = cv2.warpAffine(image10, M10, (w10, h10))

# %% [markdown]
# ## MENAMPILKAN HASIL RESIZED

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 4, 1)
plt.imshow(cv2.cvtColor(resized1, cv2.COLOR_BGR2RGB))
plt.title('Resized 1')
# Out:
# Text(0.5,1,'Resized 1')

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 4, 1)
plt.imshow(cv2.cvtColor(resized2, cv2.COLOR_BGR2RGB))
plt.title('Resized 2')
# Out:
# Text(0.5,1,'Resized 2')

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 4, 1)
plt.imshow(cv2.cvtColor(resized3, cv2.COLOR_BGR2RGB))
plt.title('Resized 3')
# Out:
# Text(0.5,1,'Resized 3')

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 4, 1)
plt.imshow(cv2.cvtColor(resized4, cv2.COLOR_BGR2RGB))
plt.title('Resized 4')
# Out:
# Text(0.5,1,'Resized 4')

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 4, 1)
plt.imshow(cv2.cvtColor(resized5, cv2.COLOR_BGR2RGB))
plt.title('Resized 5')
# Out:
# Text(0.5,1,'Resized 5')

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 4, 1)
plt.imshow(cv2.cvtColor(resized6, cv2.COLOR_BGR2RGB))
plt.title('Resized 6')
# Out:
# Text(0.5,1,'Resized 6')

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 4, 1)
plt.imshow(cv2.cvtColor(resized7, cv2.COLOR_BGR2RGB))
plt.title('Resized 7')
# Out:
# Text(0.5,1,'Resized 7')

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 4, 1)
plt.imshow(cv2.cvtColor(resized8, cv2.COLOR_BGR2RGB))
plt.title('Resized 8')
# Out:
# Text(0.5,1,'Resized 8')

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 4, 1)
plt.imshow(cv2.cvtColor(resized9, cv2.COLOR_BGR2RGB))
plt.title('Resized 9')
# Out:
# Text(0.5,1,'Resized 9')

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 4, 1)
plt.imshow(cv2.cvtColor(resized10, cv2.COLOR_BGR2RGB))
plt.title('Resized 10')
# Out:
# Text(0.5,1,'Resized 10')

# %% [markdown]
# ## MENAMPILKAN HASIL CROP

# %%
plt.subplot(1, 4, 2)
plt.imshow(cv2.cvtColor(cropped1, cv2.COLOR_BGR2RGB))
plt.title('Cropped 1')
# Out:
# Text(0.5,1,'Cropped 1')

# %%
plt.subplot(1, 4, 2)
plt.imshow(cv2.cvtColor(cropped2, cv2.COLOR_BGR2RGB))
plt.title('Cropped 2')
# Out:
# Text(0.5,1,'Cropped 2')

# %%
plt.subplot(1, 4, 2)
plt.imshow(cv2.cvtColor(cropped3, cv2.COLOR_BGR2RGB))
plt.title('Cropped 3')
# Out:
# Text(0.5,1,'Cropped 3')

# %%
plt.subplot(1, 4, 2)
plt.imshow(cv2.cvtColor(cropped5, cv2.COLOR_BGR2RGB))
plt.title('Cropped 5')
# Out:
# Text(0.5,1,'Cropped 5')

# %%
plt.subplot(1, 4, 2)
plt.imshow(cv2.cvtColor(cropped6, cv2.COLOR_BGR2RGB))
plt.title('Cropped 6')
# Out:
# Text(0.5,1,'Cropped 6')

# %%
plt.subplot(1, 4, 2)
plt.imshow(cv2.cvtColor(cropped7, cv2.COLOR_BGR2RGB))
plt.title('Cropped 7')
# Out:
# Text(0.5,1,'Cropped 7')

# %%
plt.subplot(1, 4, 2)
plt.imshow(cv2.cvtColor(cropped8, cv2.COLOR_BGR2RGB))
plt.title('Cropped 8')
# Out:
# Text(0.5,1,'Cropped 8')

# %%
plt.subplot(1, 4, 2)
plt.imshow(cv2.cvtColor(cropped9, cv2.COLOR_BGR2RGB))
plt.title('Cropped9')
# Out:
# Text(0.5,1,'Cropped9')

# %%
plt.subplot(1, 4, 2)
plt.imshow(cv2.cvtColor(cropped10, cv2.COLOR_BGR2RGB))
plt.title('Cropped 10')
# Out:
# Text(0.5,1,'Cropped 10')

# %% [markdown]
# ## MENAMPILKAN HASIL FLIP

# %%
plt.subplot(1, 4, 3)
plt.imshow(cv2.cvtColor(flipped1, cv2.COLOR_BGR2RGB))
plt.title('Flipped 1')
# Out:
# Text(0.5,1,'Flipped 1')

# %%
plt.subplot(1, 4, 3)
plt.imshow(cv2.cvtColor(flipped2, cv2.COLOR_BGR2RGB))
plt.title('Flipped 2')
# Out:
# Text(0.5,1,'Flipped 2')

# %%
plt.subplot(1, 4, 3)
plt.imshow(cv2.cvtColor(flipped3, cv2.COLOR_BGR2RGB))
plt.title('Flipped 3')
# Out:
# Text(0.5,1,'Flipped 3')

# %%
plt.subplot(1, 4, 3)
plt.imshow(cv2.cvtColor(flipped4, cv2.COLOR_BGR2RGB))
plt.title('Flipped 4')
# Out:
# Text(0.5,1,'Flipped 4')

# %%
plt.subplot(1, 4, 3)
plt.imshow(cv2.cvtColor(flipped5, cv2.COLOR_BGR2RGB))
plt.title('Flipped 5')
# Out:
# Text(0.5,1,'Flipped 5')

# %%
plt.subplot(1, 4, 3)
plt.imshow(cv2.cvtColor(flipped6, cv2.COLOR_BGR2RGB))
plt.title('Flipped 6')
# Out:
# Text(0.5,1,'Flipped 6')

# %%
plt.subplot(1, 4, 3)
plt.imshow(cv2.cvtColor(flipped7, cv2.COLOR_BGR2RGB))
plt.title('Flipped 7')
# Out:
# Text(0.5,1,'Flipped 7')

# %%
plt.subplot(1, 4, 3)
plt.imshow(cv2.cvtColor(flipped8, cv2.COLOR_BGR2RGB))
plt.title('Flipped 8')
# Out:
# Text(0.5,1,'Flipped 8')

# %%
plt.subplot(1, 4, 3)
plt.imshow(cv2.cvtColor(flipped9, cv2.COLOR_BGR2RGB))
plt.title('Flipped 9')
# Out:
# Text(0.5,1,'Flipped 9')

# %%
plt.subplot(1, 4, 3)
plt.imshow(cv2.cvtColor(flipped10, cv2.COLOR_BGR2RGB))
plt.title('Flipped 10')
# Out:
# Text(0.5,1,'Flipped 10')

# %% [markdown]
# ## MENAMPILKAN HASIL ROTATED

# %%
plt.subplot(1, 4, 4) # Menambahkan subplot untuk gambar yang dirotasi
plt.imshow(cv2.cvtColor(rotated1, cv2.COLOR_BGR2RGB))
plt.title('Rotated 1')
# Out:
# Text(0.5,1,'Rotated 1')

# %%
plt.subplot(1, 4, 4) # Menambahkan subplot untuk gambar yang dirotasi
plt.imshow(cv2.cvtColor(rotated2, cv2.COLOR_BGR2RGB))
plt.title('Rotated 2')
# Out:
# Text(0.5,1,'Rotated 2')

# %%
plt.subplot(1, 4, 4) # Menambahkan subplot untuk gambar yang dirotasi
plt.imshow(cv2.cvtColor(rotated3, cv2.COLOR_BGR2RGB))
plt.title('Rotated 3')
# Out:
# Text(0.5,1,'Rotated 3')

# %%
plt.subplot(1, 4, 4) # Menambahkan subplot untuk gambar yang dirotasi
plt.imshow(cv2.cvtColor(rotated4, cv2.COLOR_BGR2RGB))
plt.title('Rotated 4')
# Out:
# Text(0.5,1,'Rotated 4')

# %%
plt.subplot(1, 4, 4) # Menambahkan subplot untuk gambar yang dirotasi
plt.imshow(cv2.cvtColor(rotated5, cv2.COLOR_BGR2RGB))
plt.title('Rotated 5')
# Out:
# Text(0.5,1,'Rotated 5')

# %%
plt.subplot(1, 4, 4) # Menambahkan subplot untuk gambar yang dirotasi
plt.imshow(cv2.cvtColor(rotated6, cv2.COLOR_BGR2RGB))
plt.title('Rotated 6')
# Out:
# Text(0.5,1,'Rotated 6')

# %%
plt.subplot(1, 4, 4) # Menambahkan subplot untuk gambar yang dirotasi
plt.imshow(cv2.cvtColor(rotated7, cv2.COLOR_BGR2RGB))
plt.title('Rotated 7')
# Out:
# Text(0.5,1,'Rotated 7')

# %%
plt.subplot(1, 4, 4) # Menambahkan subplot untuk gambar yang dirotasi
plt.imshow(cv2.cvtColor(rotated8, cv2.COLOR_BGR2RGB))
plt.title('Rotated 8')
# Out:
# Text(0.5,1,'Rotated 8')

# %%
plt.subplot(1, 4, 4) # Menambahkan subplot untuk gambar yang dirotasi
plt.imshow(cv2.cvtColor(rotated9, cv2.COLOR_BGR2RGB))
plt.title('Rotated 9')
# Out:
# Text(0.5,1,'Rotated 9')

# %%
plt.subplot(1, 4, 4) # Menambahkan subplot untuk gambar yang dirotasi
plt.imshow(cv2.cvtColor(rotated10, cv2.COLOR_BGR2RGB))
plt.title('Rotated 10')
# Out:
# Text(0.5,1,'Rotated 10')
